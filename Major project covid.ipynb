# %%
import pandas as pd
import os

# %%
df_confirmed = pd.read_csv(r"C:\Users\91967\Desktop\sample\covid2020.csv")

# %%
df_confirmed
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 80740      ZWE    Africa     Zimbabwe  2021-04-06      36966.0       32.0
# 80741      ZWE    Africa     Zimbabwe  2021-04-07      36984.0       18.0
# 80742      ZWE    Africa     Zimbabwe  2021-04-08      37052.0       68.0
# 80743      ZWE    Africa     Zimbabwe  2021-04-09      37147.0       95.0
# 80744      ZWE    Africa     Zimbabwe  2021-04-10      37273.0      126.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_confirmed.shape
# Out:
# (80745, 59)

# %%
df_confirmed.isnull().sum()
# Out:
# iso_code                                     0
# continent                                 3931
# location                                     0
# date                                         0
# total_cases                               1653
# new_cases                                 1655
# new_cases_smoothed                        2656
# total_deaths                             11147
# new_deaths                               10989
# new_deaths_smoothed                       2656
# total_cases_per_million                   2082
# new_cases_per_million                     2084
# new_cases_smoothed_per_million            3080
# total_deaths_per_million                 11563
# new_deaths_per_million                   11405
# new_deaths_smoothed_per_million           3080
# reproduction_rate                        15625
# icu_patients                             72289
# icu_patients_per_million                 72289
# hosp_patients                            70618
# ...

# %%
df_confirmed.isnull().head()
# Out:
#    iso_code  continent  location   date  total_cases  new_cases  \
# 0     False      False     False  False        False      False
# 1     False      False     False  False        False      False
# 2     False      False     False  False        False      False
# 3     False      False     False  False        False      False
# 4     False      False     False  False        False      False
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                True          True        True                 True  ...
# 1                True          True        True                 True  ...
# 2                True          True        True                 True  ...
# 3                True          True        True                 True  ...
# 4                True          True        True                 True  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0           False             True                  False
# ...

# %%
df_confirmed[df_confirmed['continent'].isnull()]
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 412    OWID_AFR       NaN   Africa  2020-02-13          NaN        0.0
# 413    OWID_AFR       NaN   Africa  2020-02-14          1.0        1.0
# 414    OWID_AFR       NaN   Africa  2020-02-15          1.0        0.0
# 415    OWID_AFR       NaN   Africa  2020-02-16          1.0        0.0
# 416    OWID_AFR       NaN   Africa  2020-02-17          1.0        0.0
# ...         ...       ...      ...         ...          ...        ...
# 79598  OWID_WRL       NaN    World  2021-04-06  132419139.0   605501.0
# 79599  OWID_WRL       NaN    World  2021-04-07  133103485.0   684346.0
# 79600  OWID_WRL       NaN    World  2021-04-08  133943335.0   839850.0
# 79601  OWID_WRL       NaN    World  2021-04-09  134691380.0   748045.0
# 79602  OWID_WRL       NaN    World  2021-04-10  135355885.0   664505.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_confirmed.shape
# Out:
# (80745, 59)
